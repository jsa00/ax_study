# %%
number = 10
number
# Out:
# 10

# %%
number += 20
number
# Out:
# 30

# %%
number += 5
number
# Out:
# 35

# %%
# 2-2. 1
name = "조성아"
age = 25
message = "내 나이는 " + str(age) + "살입니다."

print(message)
# Out:
# 내 나이는 25살입니다.

# %%
# 2-2. 2
num1 = 10
num2 = 3.14

result = num1 + num2
print(result)

result = num1 + int(num2)
print(result)
# Out:
# 13.14
# 13

# %%
# 2-2. 3
user_input = "20세"

if user_input.isdigit():
    age = int(user_input)
    print("정수 전환 성공")
else: 
    print("숫자만 입력해 주세요!")
# Out:
# 숫자만 입력해 주세요!

# %%
# 2-3. 1
count = 10
count *= 5
print(count)
# Out:
# 50

# %%
# 2-3. 2
fruit = "apple" < "banana"
print(fruit)
# Out:
# True

# %%
# 2-3. 3
result = False and 500 // 0
print(result)
# Out:
# False

# %%
# 2-4. 1
menu_name = "Americano"
menu_price = 4500
message = "상품: %s | 가격: %d"

print(message %(menu_name, menu_price))
# Out:
# 상품: Americano | 가격: 4500

# %%
# 2-4. 2
price = 15000
print(f"금액: {price:>8,}원")
# Out:
# 금액:   15,000원

# %%
# 2-4. 3
current_status = "정산 진행중"
price = 6500

print(f"{current_status=}, {price=}")
# Out:
# current_status='정산 진행중', price=6500
