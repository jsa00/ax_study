# %%
# 필요 도구 불러오기
import platform
import torch
from torchvision import datasets
from torchvision.transforms import ToTensor  # GPU 로 연산 가능
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
# 디바이스 자동 설정
device = torch.device(
    "cuda" if torch.cuda.is_available() else 
    "mps" if torch.backends.mps.is_available() else 
    "cpu"
)

# %%
# Fashion MNIST 데이터 불러오기
raw_train_data = datasets.FashionMNIST(
    root="data", train=True, download=True, transform=ToTensor()
)
test_data = datasets.FashionMNIST(
    root="data", train=False, download=True, transform=ToTensor()
)

train_size = 50000
val_size = 10000
train_data, val_data = random_split(
    raw_train_data, [train_size, val_size], 
    generator=torch.Generator().manual_seed(10)
)

# 데이터 세트별 불러오기
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# %%
# 4장 1강 1-1 은닉 뉴런 64개와 SGD 옵티마이저 모델 설정
# 1. 첫 번째 선형 계층 정의하기
import torch.nn as nn
import torch.optim as optim

# 3. Fashion MNIST 구성하기
class FashionMNIST(nn.Module):
    def __init__(self):
        super=().__init__()
        self.flatten = nn.Flatten()
        self.linear1 = nn.Linear(28 * 28, 128)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.2)
        self.linear2 = nn.Linear(128, 10)

    # 2. 활성화 함수 ReLU 함수 연결하기
    def forward(self, x):
        out = self.flatten(x)
        out = self.linear1(out)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.linear2(out)
        return out

# 4. 파이토치 모델 구성하기
model = FashionMNIST().to(device)

total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"학습 가능한 총 파라미터 수: {total_params:,}개")

# %%
# 4장 1강 2-1 배치 크기 64 설정 및 전체 데이터 학습 순환 구조 완성
# 1. 데이터 로더 생성 구문 설정하기


# 2. 전체 훈련 데이터셋의 학습 루프 작성하기


# 3. 평균 훈련 손실값(Loss) 출력하기

# %%
# 4장 1강 3-1 은닉 뉴런 256개 및 드롭아웃 확률 50퍼센트 설정
# 1. 선형 계층의 은닉 뉴런 개수 선언하기


# 2. 드롭아웃 계층의 비활성화 확률 설정 배치하기


# 3. 평탄화, 선형 변환, ReLU 활성화, 드롭아웃, 출력층 변환의 흐름 코드 작성하기


# 총 파라미터 수 출력하기

# %%
# 4장 2강 1-1
# 1. 판다스 라이브러리에서 데이터셋 파일 로드하기
# import pandas as pd
# from sklearn.model_selection import train_test_split

# df = pd.read_csv('ratings.txt', sep='\t')

# # 2. 결측치 제거 후, Counter 클래스를 사용하여 단어의 빈도수 계산하기
# from collections import Counter
# import torch
# import torch.nn as nn
# from torch.utils.data import DataLoader, Dataset

# df = df.dropna()

# train_val_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
# train_df, val_df = train_test_split(train_val_df, test_size=0.2, random_state=42)

# vocab_size = 20000

# all_words = []
# for text in train_df['document'].astype(str):
#     all_words.extend(text.split())

# # 3. 빈도수 상위 20,000개의 단어를 골라 vocab 사전 생성하기
# counts = Counter()
# vocab = {word: i+2 for i, (word, _) in enumerate(counts.most_common(vocab_size-2))}

# vocab['<Padding Token>'] = 0
# vocab['<Unknown Token>'] = 1

# 4. 가장 자주 등장한 상위 3개의 단어와 그 단어들에 부여된 고유 숫자 번호 순서대로 출력하기

# %%
# 4장 2강 2-1

# %%
# 4장 2강 3-1
