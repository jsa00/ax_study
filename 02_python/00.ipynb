# %%
age = 20
price = 5000
print(f"나이 : {age}")
print(f"가격 : {price}")
# Out:
# 나이 : 20
# 가격 : 5000

# %%
x = 10
print(type(x))

x = "Hello"
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age = 20
print(f"값 : {age}, 주소지 : {id(age)}")

age = 25
print(f"값 : {age}, 주소지 : {id(age)}")
# Out:
# 값 : 20, 주소지 : 140716539647496
# 값 : 25, 주소지 : 140716539647656
