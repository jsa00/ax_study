# %%
x = 5000
x
# Out:
# 5000

# %%
# 주소 확인
id(x)
# Out:
# 1862133343248

# %%
y = x
y
# Out:
# 5000

# %%
id(y)
# Out:
# 1862133343248

# %%
x = 500
print(f"값 : {x}")
print(f"주소지 : {id(x)}")
# Out:
# 값 : 500
# 주소지 : 1862133344784

# %%
x = 600
print(f"값 : {x}")
print(f"주소지 : {id(x)}")
# Out:
# 값 : 600
# 주소지 : 1862133344560

# %%
x = 500
print(f"값 : {x}")
print(f"주소지 : {id(x)}")
# Out:
# 값 : 500
# 주소지 : 1862133343856

# %%
a = 10
print(f"주소지 : {id(a)}")
# Out:
# 주소지 : 140716539647176

# %%
a = 20
print(f"주소지 : {id(a)}")
# Out:
# 주소지 : 140716539647496

# %%
a = 10
print(f"주소지 : {id(a)}")
# Out:
# 주소지 : 140716539647176

# %%
number = 5
type(number)
# Out:
# int

# %%
pi = 3.14
type(pi)
# Out:
# float

# %%
result = True
type(result)
# Out:
# bool

# %%
pi = "원주율"
type(pi)
# Out:
# str
