# %% [markdown]
# # 1장 3강
#
# [단축키]
# - ctrl + enter : 실행
# - shift + enter : 실행 후 코드 추가
# - left bar 클릭 + a : 상단에 코드 추가
# - left bar 클릭 + b : 하단에 코드 추가
# - left bar 클릭 + m : 형식 마크다운로 변경
# - left bar 클릭 + y : 형식 코드로 변경
# - 상단 Restart 버튼 : 커널 초기화
#
# [주의사항]
# - 비순차 실행

# %%
print("Hello")
# Out:
# Hello

# %%
print("World!")
# Out:
# World!

# %%
print("Everyone")
# Out:
# Everyone

# %%
money = 5000

# %%
money += 2000
print(money)
# Out:
# 7000

# %%
money   # 편의상 print() 사용 없이도 출력 가능
# Out:
# 7000
