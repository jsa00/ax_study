# %% [markdown]
# # 6장 1강 : 모듈과 패키지
# 1. 독립 소스 파일 모듈(Module)
# 2. 디렉터리형 패키지(Package)
# 3. import, from, as 키워드
# 4. 파이썬 표준 라이브러리
# 5. 사용자 정의 모듈 분리 및 별칭 호출 구현

# %%
# import
import mod1

print(mod1.add(10, 20))
print(mod1.VERSION)
# Out:
# 30
# 1.0.0

# %%
# import
# from ~ import ~
from mod1 import add, minus, VERSION

print(add(10, 20))
print(VERSION)
# Out:
# 30
# 1.0.0

# %%
# import
# from ~ import *
from mod1 import *

print(add(10, 20))
print(VERSION)
# Out:
# 30
# 1.0.0

# %%
# import
# 패키지명 내부 모듈 불러오기
from utils import mod2

print(mod2.multiply(10, 20))
# Out:
# 200

# %%
# import
# 패키지 내부 모듈도 마침표(.)로 사용 가능
from utils.mod2 import multiply

multiply(10, 20)
# Out:
# 200

# %%
# import 절대 경로
# 경로에 따른 동일 함수 불러오기
# from utils.sub.mod3 import print_version

# %%
# 독립 소스 파일 모듈
import mod1

# %%
# 독립 소스 파일 모듈
# __init__.py 동작 확인
from game import lol
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 # 독립 소스 파일 모듈
#       2 # __init__.py 동작 확인
# ----> 3 from game import lol
#
# File ~\Documents\ax_study\02_python\chapter06\game\__init__.py:1
# ----> 1 from lol import LOL
#       3 print("공통 초기화 작업을 수행합니다...")
#       5 def common_func():
#
# ModuleNotFoundError: No module named 'lol'

# %%
# 독립 소스 파일 모듈
# __init__.py으로 패키지의 공통 작업 수행 확인
import game
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 # 독립 소스 파일 모듈
#       2 # __init__.py으로 패키지의 공통 작업 수행 확인
# ----> 3 import game
#
# File ~\Documents\ax_study\02_python\chapter06\game\__init__.py:1
# ----> 1 from lol import LOL
#       3 print("공통 초기화 작업을 수행합니다...")
#       5 def common_func():
#
# ModuleNotFoundError: No module named 'lol'

# %%
game.common_func()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 game.common_func()
#
# NameError: name 'game' is not defined

# %%
from game import *

LOL
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from game import *
#       2
#       3 LOL
#
# File ~\Documents\ax_study\02_python\chapter06\game\__init__.py:1
# ----> 1 from lol import LOL
#       3 print("공통 초기화 작업을 수행합니다...")
#       5 def common_func():
#
# ModuleNotFoundError: No module named 'lol'

# %%
# import
# as로 별칭 붙이기
import mod1 as m

m.add(10, 20)
# Out:
# 30
